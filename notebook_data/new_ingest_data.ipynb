# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType, TimestampType, DateType
from pyspark.sql.functions import col, explode, struct, collect_list, element_at, lit
import requests
import json
import psycopg2
from psycopg2.extras import execute_values

# %%
spark = SparkSession.builder \
    .appName("mini-project") \
    .getOrCreate()

# %%
api = "https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations.json?includeTimeseries=true&hasTimeseries=WV&includeForecastTimeseries=true"
responses = requests.get(api).json()

# %%
stations_data = []
timeseries_data = []

# %%
for station in responses:
    # Station entry
    station_entry = {
        "uuid": station["uuid"],
        "number": station["number"],
        "shortname": station["shortname"],
        "longname": station["longname"],
        "km": station["km"],
        "agency": station["agency"],
        "longitude": station["longitude"],
        "latitude": station["latitude"],
        "water_shortname": station["water"]["shortname"],
        "water_longname": station["water"]["longname"]
    }
    
    # Append station data if not already in list
    if station_entry not in stations_data:
        stations_data.append(station_entry)

    # Timeseries data for the current station
    for ts in station["timeseries"]:
        timeseries_entry = {
            "station_uuid": station["uuid"],
            "shortname": ts.get("shortname"),
            "longname": ts.get("longname"),
            "unit": ts.get("unit"),
            "equidistance": ts.get("equidistance"),
            "timeseries_start": ts.get("start"),
            "timeseries_end": ts.get("end"),
            "comment_shortDescription": ts.get("comment", {}).get("shortDescription"),
            "comment_longDescription": ts.get("comment", {}).get("longDescription"),
            "gaugeZero_unit": ts.get("gaugeZero", {}).get("unit"),
            "gaugeZero_value": ts.get("gaugeZero", {}).get("value"),
            "gaugeZero_validFrom": ts.get("gaugeZero", {}).get("validFrom")
        }
        # Append timeseries entry
        timeseries_data.append(timeseries_entry)

# %%
station_schema = StructType([
    StructField("uuid", StringType(), True),
    StructField("number", StringType(), True),
    StructField("shortname", StringType(), True),
    StructField("longname", StringType(), True),
    StructField("km", DoubleType(), True),
    StructField("agency", StringType(), True),
    StructField("longitude", DoubleType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("water_shortname", StringType(), True),
    StructField("water_longname", StringType(), True)
])

# %%
timeseries_schema = StructType([
    StructField("station_uuid", StringType(), True),
    StructField("shortname", StringType(), True),
    StructField("longname", StringType(), True),
    StructField("unit", StringType(), True),
    StructField("equidistance", IntegerType(), True),
    StructField("timeseries_start", TimestampType(), True),
    StructField("timeseries_end", TimestampType(), True),
    StructField("comment_shortDescription", StringType(), True),
    StructField("comment_longDescription", StringType(), True),
    StructField("gaugeZero_unit", StringType(), True),
    StructField("gaugeZero_value", DoubleType(), True),
    StructField("gaugeZero_validFrom", DateType(), True)
])

# %%
# Convert to JSON string
stations_str = json.dumps(stations_data)
timeseries_str = json.dumps(timeseries_data)

# Load the JSON string into Spark DataFrames
stations_df = spark.read.json(spark.sparkContext.parallelize([stations_str]), schema=station_schema)
timeseries_df = spark.read.json(spark.sparkContext.parallelize([timeseries_str]), schema=timeseries_schema)

# %%
# Print schema and data to verify
stations_df.printSchema()
timeseries_df.printSchema()
# Out:
# root
#  |-- uuid: string (nullable = true)
#  |-- number: string (nullable = true)
#  |-- shortname: string (nullable = true)
#  |-- longname: string (nullable = true)
#  |-- km: double (nullable = true)
#  |-- agency: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- water_shortname: string (nullable = true)
#  |-- water_longname: string (nullable = true)
#
# root
#  |-- station_uuid: string (nullable = true)
#  |-- shortname: string (nullable = true)
#  |-- longname: string (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- equidistance: integer (nullable = true)
#  |-- timeseries_start: timestamp (nullable = true)
#  |-- timeseries_end: timestamp (nullable = true)
#  |-- comment_shortDescription: string (nullable = true)
#  |-- comment_longDescription: string (nullable = true)
#  |-- gaugeZero_unit: string (nullable = true)
#  |-- gaugeZero_value: double (nullable = true)
#  |-- gaugeZero_validFrom: date (nullable = true)

# %%
# Verify the contents of DataFrames
print("Sample of stations_df:")
print(stations_df.head(5))
print("Sample of timeseries_df:")
print(timeseries_df.head(5))
# Out:
# Sample of stations_df:
# [Row(uuid='e6d68ab7-5c27-4f25-896f-11dbf04056cd', number='10089006', shortname='VILSHOFEN', longname='VILSHOFEN', km=2249.5, agency='STANDORT REGENSBURG', longitude=13.182352727075328, latitude=48.63719446076585, water_shortname='DONAU', water_longname='DONAU'), Row(uuid='616dd98e-816d-4e17-b8cd-57b163dbc8a2', number='10088003', shortname='HOFKIRCHEN', longname='HOFKIRCHEN', km=2256.9, agency='STANDORT REGENSBURG', longitude=13.115159742918724, latitude=48.676629660669875, water_shortname='DONAU', water_longname='DONAU'), Row(uuid='53d40547-8a09-4b25-988c-2e6d8d8d98ee', number='10081004', shortname='DEGGENDORF', longname='DEGGENDORF', km=2284.4, agency='STANDORT REGENSBURG', longitude=12.962349954256105, latitude=48.824943730974475, water_shortname='DONAU', water_longname='DONAU'), Row(uuid='7fe63a95-8ff6-4cff-9a29-a124136516b5', number='10078000', shortname='PFELLING', longname='PFELLING', km=2305.5, agency='STANDORT REGENSBURG', longitude=12.74721651873093, latitude=48.87976613950202, water_shortname='DONAU', water_longname='DONAU'), Row(uuid='7cb7461b-3530-4c01-8978-7f676b8f71ed', number='501010', shortname='SCHÖNA', longname='SCHÖNA', km=2.05, agency='STANDORT DRESDEN', longitude=14.235228651495222, latitude=50.87576232293828, water_shortname='ELBE', water_longname='ELBE')]
# Sample of timeseries_df:
# [Row(station_uuid='e6d68ab7-5c27-4f25-896f-11dbf04056cd', shortname='W', longname='WASSERSTAND ROHDATEN', unit='cm', equidistance=15, timeseries_start=None, timeseries_end=None, comment_shortDescription=None, comment_longDescription=None, gaugeZero_unit='m. ü. NHN', gaugeZero_value=297.043, gaugeZero_validFrom=datetime.date(2019, 1, 1)), Row(station_uuid='e6d68ab7-5c27-4f25-896f-11dbf04056cd', shortname='WV', longname='WASSERSTANDVORHERSAGE', unit='cm', equidistance=120, timeseries_start=datetime.datetime(2024, 7, 13, 9, 0), timeseries_end=datetime.datetime(2024, 7, 17, 3, 0), comment_shortDescription='nwv-bfg', comment_longDescription='Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', gaugeZero_unit=None, gaugeZero_value=None, gaugeZero_validFrom=None), Row(station_uuid='e6d68ab7-5c27-4f25-896f-11dbf04056cd', shortname='LT', longname='LUFTTEMPERATUR', unit='°C', equidistance=60, timeseries_start=None, timeseries_end=None, comment_shortDescription=None, comment_longDescription=None, gaugeZero_unit=None, gaugeZero_value=None, gaugeZero_validFrom=None), Row(station_uuid='e6d68ab7-5c27-4f25-896f-11dbf04056cd', shortname='WT', longname='WASSERTEMPERATUR', unit='°C', equidistance=60, timeseries_start=None, timeseries_end=None, comment_shortDescription='Wassertemperatursonde ausgefallen.', comment_longDescription='Wassertemperatursonde ausgefallen. Sonde beschafft, jedoch Tauchereinsatz erforderlich.', gaugeZero_unit=None, gaugeZero_value=None, gaugeZero_validFrom=None), Row(station_uuid='616dd98e-816d-4e17-b8cd-57b163dbc8a2', shortname='W', longname='WASSERSTAND ROHDATEN', unit='cm', equidistance=15, timeseries_start=None, timeseries_end=None, comment_shortDescription=None, comment_longDescription=None, gaugeZero_unit='m. ü. NHN', gaugeZero_value=299.575, gaugeZero_validFrom=datetime.date(2019, 11, 1))]

# %%
# Convert Spark DataFrames to list of tuples for insertion into PostgreSQL
stations_data_list = [tuple(row) for row in stations_df.collect()]
timeseries_data_list = [tuple(row) for row in timeseries_df.collect()]

# %%
# Define the columns
stations_columns = [
    "uuid", "number", "shortname", "longname", "km", "agency",
    "longitude", "latitude", "water_shortname", "water_longname"
]

timeseries_columns = [
    "station_uuid", "shortname", "longname", "unit", "equidistance",
    "timeseries_start", "timeseries_end", "comment_shortDescription", "comment_longDescription",
    "gaugeZero_unit", "gaugeZero_value", "gaugeZero_validFrom"
]

# %%
# Define the PostgreSQL table schema and create the tables
create_stations_table_query = """
CREATE TABLE IF NOT EXISTS stations (
    uuid UUID PRIMARY KEY,
    number VARCHAR(255),
    shortname VARCHAR(255),
    longname VARCHAR(255),
    km DOUBLE PRECISION,
    agency VARCHAR(255),
    longitude DOUBLE PRECISION,
    latitude DOUBLE PRECISION,
    water_shortname VARCHAR(255),
    water_longname VARCHAR(255)
);
"""

create_timeseries_table_query = """
CREATE TABLE IF NOT EXISTS timeseries (
    id SERIAL PRIMARY KEY,
    station_uuid UUID REFERENCES stations(uuid),
    shortname VARCHAR(255),
    longname VARCHAR(255),
    unit VARCHAR(50),
    equidistance INTEGER,
    timeseries_start TIMESTAMPTZ,
    timeseries_end TIMESTAMPTZ,
    comment_shortDescription TEXT,
    comment_longDescription TEXT,
    gaugeZero_unit VARCHAR(50),
    gaugeZero_value DOUBLE PRECISION,
    gaugeZero_validFrom DATE
);
"""

# %%
# Database connection parameters
conn_params = {
    "dbname": "db",
    "user": "postgres",
    "password": "12345",
    "host": "pg_container",
    "port": 5432
}

# Function to create the tables
def create_tables():
    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()
    cursor.execute(create_stations_table_query)
    cursor.execute(create_timeseries_table_query)
    conn.commit()
    cursor.close()
    conn.close()

create_tables()

# Function to insert data into PostgreSQL
def insert_data(table, data, columns):
    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()
    insert_query = f"INSERT INTO {table} ({', '.join(columns)}) VALUES %s"
    execute_values(cursor, insert_query, data)
    conn.commit()
    cursor.close()
    conn.close()

# %%
# Insert station data into PostgreSQL
insert_data("stations", stations_data_list, stations_columns)

# Insert timeseries data into PostgreSQL
insert_data("timeseries", timeseries_data_list, timeseries_columns)

# Verify the insertion
conn = psycopg2.connect(**conn_params)
cursor = conn.cursor()
cursor.execute("SELECT * FROM stations")
stations_rows = cursor.fetchall()
for row in stations_rows:
    print(row)

cursor.execute("SELECT * FROM timeseries")
timeseries_rows = cursor.fetchall()
for row in timeseries_rows:
    print(row)

cursor.close()
conn.close()
# Out:
# ('e6d68ab7-5c27-4f25-896f-11dbf04056cd', '10089006', 'VILSHOFEN', 'VILSHOFEN', 2249.5, 'STANDORT REGENSBURG', 13.182352727075328, 48.63719446076585, 'DONAU', 'DONAU')
# ('616dd98e-816d-4e17-b8cd-57b163dbc8a2', '10088003', 'HOFKIRCHEN', 'HOFKIRCHEN', 2256.9, 'STANDORT REGENSBURG', 13.115159742918724, 48.676629660669875, 'DONAU', 'DONAU')
# ('53d40547-8a09-4b25-988c-2e6d8d8d98ee', '10081004', 'DEGGENDORF', 'DEGGENDORF', 2284.4, 'STANDORT REGENSBURG', 12.962349954256105, 48.824943730974475, 'DONAU', 'DONAU')
# ('7fe63a95-8ff6-4cff-9a29-a124136516b5', '10078000', 'PFELLING', 'PFELLING', 2305.5, 'STANDORT REGENSBURG', 12.74721651873093, 48.87976613950202, 'DONAU', 'DONAU')
# ('7cb7461b-3530-4c01-8978-7f676b8f71ed', '501010', 'SCHÖNA', 'SCHÖNA', 2.05, 'STANDORT DRESDEN', 14.235228651495222, 50.87576232293828, 'ELBE', 'ELBE')
# ('70272185-b2b3-4178-96b8-43bea330dcae', '501060', 'DRESDEN', 'DRESDEN', 55.63, 'STANDORT DRESDEN', 13.738831783620384, 51.054459765598125, 'ELBE', 'ELBE')
# ('b04b739d-7ffa-41ee-9eb9-95cb1b4ef508', '501110', 'RIESA', 'RIESA', 108.4, 'STANDORT DRESDEN', 13.29334052168511, 51.31148159700113, 'ELBE', 'ELBE')
# ('83bbaedb-5d81-4bc6-9f66-3bd700c99c1f', '501261', 'TORGAU', 'TORGAU', 154.15, 'STANDORT DRESDEN', 13.01013060185494, 51.55368454231443, 'ELBE', 'ELBE')
# ('070b1eb4-3872-4e07-b2e5-e25fd9251b93', '501420', 'WITTENBERG', 'WITTENBERG', 214.14, 'STANDORT DRESDEN', 12.646310954043884, 51.8565291449134, 'ELBE', 'ELBE')
# ('ae93f2a5-612e-4514-b5fd-9c8aecdd73c7', '501480', 'VOCKERODE', 'VOCKERODE', 245.62, 'STANDORT DRESDEN', 12.355386908862236, 51.851332646269746, 'ELBE', 'ELBE')
# ('1edc5fa4-88af-47f5-95a4-0e77a06fe8b1', '502000', 'DESSAU', 'DESSAU', 261.16, 'STANDORT DRESDEN', 12.22327683144822, 51.856888350666324, 'ELBE', 'ELBE')
# ('094b96e5-caeb-46d3-a8ee-d44182add069', '502010', 'AKEN', 'AKEN', 274.75, 'STANDORT DRESDEN', 12.058859064366539, 51.857867459889704, 'ELBE', 'ELBE')
# ('939f82ec-15a9-49c8-8828-dc2f8a2d49e2', '502070', 'BARBY', 'BARBY', 294.82, 'STANDORT MAGDEBURG', 11.882246426452303, 51.984833781910986, 'ELBE', 'ELBE')
# ('ccccb57f-a2f9-4183-ae88-5710d3afaefd', '502180', 'MAGDEBURG-STROMBRÜCKE', 'MAGDEBURG-STROMBRÜCKE', 326.67, 'STANDORT MAGDEBURG', 11.644334378196522, 52.12969780011619, 'ELBE', 'ELBE')
# ('e30f2e83-b80b-4b96-8f39-fa60317afcc7', '502210', 'ROTHENSEE', 'ROTHENSEE', 333.12, 'STANDORT MAGDEBURG', 11.68265328901543, 52.1809527613989, 'ELBE', 'ELBE')
# ('3adf88fd-fd7a-41d0-84f5-1143c98a6564', '502240', 'NIEGRIPP AP', 'NIEGRIPP AP', 343.6, 'STANDORT MAGDEBURG', 11.737554478861217, 52.24974836387516, 'ELBE', 'ELBE')
# ('13e91b77-90f3-41a5-a320-641748e9c311', '502350', 'TANGERMÜNDE', 'TANGERMÜNDE', 388.26, 'STANDORT MAGDEBURG', 11.978056091329778, 52.541306122508246, 'ELBE', 'ELBE')
# ('f4c55f77-ab80-4e00-bed3-aa6631aba074', '502430', 'SANDAU', 'SANDAU', 416.06, 'STANDORT MAGDEBURG', 12.031305110634692, 52.78476981254726, 'ELBE', 'ELBE')
# ('cbf3cd49-91bd-49cc-8926-ccc6c0e7eca4', '503050', 'WITTENBERGE', 'WITTENBERGE', 453.98, 'STANDORT MAGDEBURG', 11.75944299732184, 52.985528648267035, 'ELBE', 'ELBE')
# ('6e3ea719-48b1-408a-bc55-0986c1e94cd5', '5910025', 'DÖMITZ', 'DÖMITZ', 504.7, 'STANDORT LAUENBURG', 11.242911991019788, 53.14033320310089, 'ELBE', 'ELBE')
# ('67d6e882-b60c-40d3-975c-a6d7a2b4e40a', '5930010', 'NEU DARCHAU', 'NEU DARCHAU', 536.385, 'STANDORT LAUENBURG', 10.888818550302116, 53.232257595868504, 'ELBE', 'ELBE')
# ('33e0bce0-13df-4ffc-be9d-f1a79e795e1c', '5930033', 'BOIZENBURG', 'BOIZENBURG', 558.534, 'STANDORT LAUENBURG', 10.717767373387286, 53.37546858798372, 'ELBE', 'ELBE')
# ('d9289367-c8aa-4b6a-b1ad-857fec94c6bb', '5930040', 'HOHNSTORF', 'HOHNSTORF', 568.987, 'STANDORT LAUENBURG', 10.558835867409144, 53.3662640634696, 'ELBE', 'ELBE')
# ('665be0fe-5e38-43f6-8b04-02a93bdbeeb4', '25100300', 'OESTRICH', 'OESTRICH', 518.08, 'STANDORT BINGEN', 8.030047855742517, 50.0028663802692, 'RHEIN', 'RHEIN')
# ('1d26e504-7f9e-480a-b52c-5932be6549ab', '25700100', 'KAUB', 'KAUB', 546.3, 'STANDORT BINGEN', 7.764961728401987, 50.08543848618328, 'RHEIN', 'RHEIN')
# ('4c7d796a-39f2-4f26-97a9-3aad01713e29', '25900700', 'KOBLENZ', 'KOBLENZ', 591.49, 'STANDORT BINGEN', 7.604740541656208, 50.35863951540208, 'RHEIN', 'RHEIN')
# ('a6ee8177-107b-47dd-bcfd-30960ccc6e9c', '2730010', 'KÖLN', 'KÖLN', 688.0, 'STANDORT KÖLN', 6.963300159749651, 50.93694929574385, 'RHEIN', 'RHEIN')
# ('8f7e5f92-1153-4f93-acba-ca48670c8ca9', '2750010', 'DÜSSELDORF', 'DÜSSELDORF', 744.2, 'STANDORT KÖLN', 6.769891254460824, 51.225498438985994, 'RHEIN', 'RHEIN')
# ('c0f51e35-d0e8-4318-afaf-c5fcbc29f4c1', '2770010', 'DUISBURG-RUHRORT', 'DUISBURG-RUHRORT', 780.8, 'STANDORT DUISBURG', 6.7279266718157364, 51.45534495315814, 'RHEIN', 'RHEIN')
# ('9598e4cb-0849-401e-bba0-689234b27644', '2790020', 'EMMERICH', 'EMMERICH', 851.9, 'STANDORT DUISBURG', 6.245594383748813, 51.829251607500346, 'RHEIN', 'RHEIN')
# ('46a3350b-f3e6-4f5d-a297-2652c43bfac8', '570930', 'CALBE UP', 'CALBE UP', 19.67, 'STANDORT MAGDEBURG', 11.788818573156826, 51.906279202606136, 'SAALE', 'SAALE')
# ('c203d5fb-96d7-4643-b2ef-b13b1d88c75b', '580790', 'HAVELBERG STADT', 'HAVELBERG STADT', 145.261, 'STANDORT BRANDENBURG', 12.07656242020758, 52.82320069362668, 'UHW', 'UNTERE HAVEL-WASSERSTRASSE')
# (1, 'e6d68ab7-5c27-4f25-896f-11dbf04056cd', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 297.043, datetime.date(2019, 1, 1))
# (2, 'e6d68ab7-5c27-4f25-896f-11dbf04056cd', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 17, 3, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (3, 'e6d68ab7-5c27-4f25-896f-11dbf04056cd', 'LT', 'LUFTTEMPERATUR', '°C', 60, None, None, None, None, None, None, None)
# (4, 'e6d68ab7-5c27-4f25-896f-11dbf04056cd', 'WT', 'WASSERTEMPERATUR', '°C', 60, None, None, 'Wassertemperatursonde ausgefallen.', 'Wassertemperatursonde ausgefallen. Sonde beschafft, jedoch Tauchereinsatz erforderlich.', None, None, None)
# (5, '616dd98e-816d-4e17-b8cd-57b163dbc8a2', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 299.575, datetime.date(2019, 11, 1))
# (6, '616dd98e-816d-4e17-b8cd-57b163dbc8a2', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 3, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (7, '616dd98e-816d-4e17-b8cd-57b163dbc8a2', 'LT', 'LUFTTEMPERATUR', '°C', 60, None, None, None, None, None, None, None)
# (8, '616dd98e-816d-4e17-b8cd-57b163dbc8a2', 'WT', 'WASSERTEMPERATUR', '°C', 60, None, None, None, None, None, None, None)
# (9, '616dd98e-816d-4e17-b8cd-57b163dbc8a2', 'Q', 'ABFLUSS', 'm³/s', 15, None, None, None, None, None, None, None)
# (10, '53d40547-8a09-4b25-988c-2e6d8d8d98ee', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 306.972, datetime.date(2019, 11, 1))
# (11, '53d40547-8a09-4b25-988c-2e6d8d8d98ee', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 15, 3, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (12, '53d40547-8a09-4b25-988c-2e6d8d8d98ee', 'LT', 'LUFTTEMPERATUR', '°C', 60, None, None, None, None, None, None, None)
# (13, '53d40547-8a09-4b25-988c-2e6d8d8d98ee', 'WT', 'WASSERTEMPERATUR', '°C', 60, None, None, None, None, None, None, None)
# (14, '7fe63a95-8ff6-4cff-9a29-a124136516b5', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 308.123, datetime.date(2019, 11, 1))
# (15, '7fe63a95-8ff6-4cff-9a29-a124136516b5', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 15, 3, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (16, '7fe63a95-8ff6-4cff-9a29-a124136516b5', 'LT', 'LUFTTEMPERATUR', '°C', 60, None, None, None, None, None, None, None)
# (17, '7fe63a95-8ff6-4cff-9a29-a124136516b5', 'Q', 'ABFLUSS', 'm³/s', 15, None, None, None, None, None, None, None)
# (18, '7cb7461b-3530-4c01-8978-7f676b8f71ed', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 116.2, datetime.date(2019, 11, 1))
# (19, '7cb7461b-3530-4c01-8978-7f676b8f71ed', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (20, '7cb7461b-3530-4c01-8978-7f676b8f71ed', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 14, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (21, '70272185-b2b3-4178-96b8-43bea330dcae', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 14, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (22, '70272185-b2b3-4178-96b8-43bea330dcae', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 102.7, datetime.date(2019, 11, 1))
# (23, '70272185-b2b3-4178-96b8-43bea330dcae', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (24, 'b04b739d-7ffa-41ee-9eb9-95cb1b4ef508', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 88.022, datetime.date(2019, 11, 1))
# (25, 'b04b739d-7ffa-41ee-9eb9-95cb1b4ef508', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (26, 'b04b739d-7ffa-41ee-9eb9-95cb1b4ef508', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 14, 4, 0, tzinfo=datetime.timezone.utc), 'bfg', 'Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten.', None, None, None)
# (27, '83bbaedb-5d81-4bc6-9f66-3bd700c99c1f', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 75.158, datetime.date(2019, 11, 1))
# (28, '83bbaedb-5d81-4bc6-9f66-3bd700c99c1f', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 15, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (29, '83bbaedb-5d81-4bc6-9f66-3bd700c99c1f', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (30, '070b1eb4-3872-4e07-b2e5-e25fd9251b93', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 62.45, datetime.date(2019, 11, 1))
# (31, '070b1eb4-3872-4e07-b2e5-e25fd9251b93', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (32, '070b1eb4-3872-4e07-b2e5-e25fd9251b93', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (33, 'ae93f2a5-612e-4514-b5fd-9c8aecdd73c7', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 55.948, datetime.date(2019, 11, 1))
# (34, 'ae93f2a5-612e-4514-b5fd-9c8aecdd73c7', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (35, 'ae93f2a5-612e-4514-b5fd-9c8aecdd73c7', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 4, 0, tzinfo=datetime.timezone.utc), 'bfg', 'Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten.', None, None, None)
# (36, '1edc5fa4-88af-47f5-95a4-0e77a06fe8b1', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 52.961, datetime.date(2019, 11, 1))
# (37, '1edc5fa4-88af-47f5-95a4-0e77a06fe8b1', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (38, '094b96e5-caeb-46d3-a8ee-d44182add069', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (39, '094b96e5-caeb-46d3-a8ee-d44182add069', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 50.217, datetime.date(2019, 11, 1))
# (40, '094b96e5-caeb-46d3-a8ee-d44182add069', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (41, '939f82ec-15a9-49c8-8828-dc2f8a2d49e2', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 17, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (42, '939f82ec-15a9-49c8-8828-dc2f8a2d49e2', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 46.125, datetime.date(2019, 11, 1))
# (43, '939f82ec-15a9-49c8-8828-dc2f8a2d49e2', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (44, 'ccccb57f-a2f9-4183-ae88-5710d3afaefd', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 39.895, datetime.date(2019, 11, 1))
# (45, 'ccccb57f-a2f9-4183-ae88-5710d3afaefd', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 17, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (46, 'ccccb57f-a2f9-4183-ae88-5710d3afaefd', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (47, 'e30f2e83-b80b-4b96-8f39-fa60317afcc7', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 37.203, datetime.date(2019, 11, 1))
# (48, 'e30f2e83-b80b-4b96-8f39-fa60317afcc7', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (49, 'e30f2e83-b80b-4b96-8f39-fa60317afcc7', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (50, '3adf88fd-fd7a-41d0-84f5-1143c98a6564', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 34.414, datetime.date(2019, 11, 1))
# (51, '3adf88fd-fd7a-41d0-84f5-1143c98a6564', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 17, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (52, '13e91b77-90f3-41a5-a320-641748e9c311', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 27.556, datetime.date(2019, 11, 1))
# (53, '13e91b77-90f3-41a5-a320-641748e9c311', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 18, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (54, '13e91b77-90f3-41a5-a320-641748e9c311', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (55, 'f4c55f77-ab80-4e00-bed3-aa6631aba074', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 22.454, datetime.date(2019, 11, 1))
# (56, 'f4c55f77-ab80-4e00-bed3-aa6631aba074', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 18, 4, 0, tzinfo=datetime.timezone.utc), 'bfg', 'Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten.', None, None, None)
# (57, 'cbf3cd49-91bd-49cc-8926-ccc6c0e7eca4', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 16.707, datetime.date(2019, 11, 1))
# (58, 'cbf3cd49-91bd-49cc-8926-ccc6c0e7eca4', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 19, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (59, 'cbf3cd49-91bd-49cc-8926-ccc6c0e7eca4', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (60, '6e3ea719-48b1-408a-bc55-0986c1e94cd5', 'W', 'WASSERSTAND ROHDATEN', 'cm', 1, None, None, None, None, 'm. ü. NHN', 10.402, datetime.date(2017, 11, 1))
# (61, '6e3ea719-48b1-408a-bc55-0986c1e94cd5', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 19, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (62, '67d6e882-b60c-40d3-975c-a6d7a2b4e40a', 'W', 'WASSERSTAND ROHDATEN', 'cm', 1, None, None, None, None, 'm. ü. NHN', 5.658, datetime.date(2017, 11, 1))
# (63, '67d6e882-b60c-40d3-975c-a6d7a2b4e40a', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 20, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (64, '67d6e882-b60c-40d3-975c-a6d7a2b4e40a', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 1, None, None, None, None, None, None, None)
# (65, '33e0bce0-13df-4ffc-be9d-f1a79e795e1c', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 20, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (66, '33e0bce0-13df-4ffc-be9d-f1a79e795e1c', 'W', 'WASSERSTAND ROHDATEN', 'cm', 1, None, None, None, None, 'm. ü. NHN', 3.774, datetime.date(2017, 11, 1))
# (67, 'd9289367-c8aa-4b6a-b1ad-857fec94c6bb', 'W', 'WASSERSTAND ROHDATEN', 'cm', 1, None, None, None, None, 'm. ü. NHN', -0.031, datetime.date(2019, 11, 1))
# (68, 'd9289367-c8aa-4b6a-b1ad-857fec94c6bb', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 20, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (69, '665be0fe-5e38-43f6-8b04-02a93bdbeeb4', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 77.562, datetime.date(2019, 11, 1))
# (70, '665be0fe-5e38-43f6-8b04-02a93bdbeeb4', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 5, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (71, '1d26e504-7f9e-480a-b52c-5932be6549ab', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 67.669, datetime.date(2019, 11, 1))
# (72, '1d26e504-7f9e-480a-b52c-5932be6549ab', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 5, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (73, '1d26e504-7f9e-480a-b52c-5932be6549ab', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (74, '4c7d796a-39f2-4f26-97a9-3aad01713e29', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 57.692, datetime.date(2019, 11, 1))
# (75, '4c7d796a-39f2-4f26-97a9-3aad01713e29', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 5, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (76, 'a6ee8177-107b-47dd-bcfd-30960ccc6e9c', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 35.038, datetime.date(2019, 11, 1))
# (77, 'a6ee8177-107b-47dd-bcfd-30960ccc6e9c', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 5, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (78, 'a6ee8177-107b-47dd-bcfd-30960ccc6e9c', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (79, 'a6ee8177-107b-47dd-bcfd-30960ccc6e9c', 'WT', 'WASSERTEMPERATUR ROHDATEN', '°C', 15, None, None, None, None, None, None, None)
# (80, '8f7e5f92-1153-4f93-acba-ca48670c8ca9', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 24.529, datetime.date(2019, 11, 1))
# (81, '8f7e5f92-1153-4f93-acba-ca48670c8ca9', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 5, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (82, '8f7e5f92-1153-4f93-acba-ca48670c8ca9', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (83, 'c0f51e35-d0e8-4318-afaf-c5fcbc29f4c1', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 16.106, datetime.date(2019, 11, 1))
# (84, 'c0f51e35-d0e8-4318-afaf-c5fcbc29f4c1', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 5, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (85, 'c0f51e35-d0e8-4318-afaf-c5fcbc29f4c1', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (86, '9598e4cb-0849-401e-bba0-689234b27644', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 7.998, datetime.date(2019, 11, 1))
# (87, '9598e4cb-0849-401e-bba0-689234b27644', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 9, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 16, 5, 0, tzinfo=datetime.timezone.utc), 'nwv-bfg', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde', None, None, None)
# (88, '9598e4cb-0849-401e-bba0-689234b27644', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
# (89, '46a3350b-f3e6-4f5d-a297-2652c43bfac8', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 48.105, datetime.date(2019, 11, 1))
# (90, '46a3350b-f3e6-4f5d-a297-2652c43bfac8', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 14, 4, 0, tzinfo=datetime.timezone.utc), 'wsa-md', 'Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.', None, None, None)
# (91, 'c203d5fb-96d7-4643-b2ef-b13b1d88c75b', 'WV', 'WASSERSTANDVORHERSAGE', 'cm', 120, datetime.datetime(2024, 7, 13, 8, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 18, 4, 0, tzinfo=datetime.timezone.utc), 'bfg', 'Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten.', None, None, None)
# (92, 'c203d5fb-96d7-4643-b2ef-b13b1d88c75b', 'W', 'WASSERSTAND ROHDATEN', 'cm', 15, None, None, None, None, 'm. ü. NHN', 21.561, datetime.date(2019, 11, 1))
# (93, 'c203d5fb-96d7-4643-b2ef-b13b1d88c75b', 'Q', 'ABFLUSS_ROHDATEN', 'm³/s', 15, None, None, None, None, None, None, None)
