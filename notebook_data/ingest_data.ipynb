# %%
from pyspark.sql import SparkSession
from pyspark.sql.window import Window
from pyspark.sql.functions import col, explode, struct, collect_list, element_at, first, row_number, concat, from_json, udf
from pyspark.sql.types import FloatType, StructType, StructField, StringType, IntegerType, MapType, ArrayType
import requests
import json

# %%
spark = SparkSession.builder \
    .appName("mini-project") \
    .getOrCreate()

# %%
api = "https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations.json?includeTimeseries=true&hasTimeseries=WV&includeForecastTimeseries=true"
responses = requests.get(api).json()
print(responses[0])
# Out:
# {'uuid': 'e6d68ab7-5c27-4f25-896f-11dbf04056cd', 'number': '10089006', 'shortname': 'VILSHOFEN', 'longname': 'VILSHOFEN', 'km': 2249.5, 'agency': 'STANDORT REGENSBURG', 'longitude': 13.182352727075328, 'latitude': 48.63719446076585, 'water': {'shortname': 'DONAU', 'longname': 'DONAU'}, 'timeseries': [{'shortname': 'W', 'longname': 'WASSERSTAND ROHDATEN', 'unit': 'cm', 'equidistance': 15, 'gaugeZero': {'unit': 'm. ü. NHN', 'value': 297.043, 'validFrom': '2019-01-01'}}, {'shortname': 'WV', 'longname': 'WASSERSTANDVORHERSAGE', 'unit': 'cm', 'equidistance': 120, 'start': '2024-07-18T19:00:00+02:00', 'end': '2024-07-22T05:00:00+02:00', 'comment': {'shortDescription': 'nwv-bfg', 'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}}, {'shortname': 'LT', 'longname': 'LUFTTEMPERATUR', 'unit': '°C', 'equidistance': 60}, {'shortname': 'WT', 'longname': 'WASSERTEMPERATUR', 'unit': '°C', 'equidistance': 60, 'comment': {'shortDescription': 'Wassertemperatursonde ausgefallen.', 'longDescription': 'Wassertemperatursonde ausgefallen. Sonde beschafft, jedoch Tauchereinsatz erforderlich.'}}]}

# %%
timeseries_data = [(response['uuid'], response['uuid']+str(item_id), json.dumps(item)) 
                   for response in responses
                   for item_id, item in enumerate(response['timeseries'])]
[item.pop('timeseries') for item in responses]
# Out:
# [[{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 297.043,
#     'validFrom': '2019-01-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-22T05:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'LT',
#    'longname': 'LUFTTEMPERATUR',
#    'unit': '°C',
#    'equidistance': 60},
#   {'shortname': 'WT',
#    'longname': 'WASSERTEMPERATUR',
#    'unit': '°C',
#    'equidistance': 60,
#    'comment': {'shortDescription': 'Wassertemperatursonde ausgefallen.',
#     'longDescription': 'Wassertemperatursonde ausgefallen. Sonde beschafft, jedoch Tauchereinsatz erforderlich.'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 299.575,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-21T05:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'LT',
#    'longname': 'LUFTTEMPERATUR',
#    'unit': '°C',
#    'equidistance': 60},
#   {'shortname': 'WT',
#    'longname': 'WASSERTEMPERATUR',
#    'unit': '°C',
#    'equidistance': 60},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 306.972,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-20T05:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'LT',
#    'longname': 'LUFTTEMPERATUR',
#    'unit': '°C',
#    'equidistance': 60},
#   {'shortname': 'WT',
#    'longname': 'WASSERTEMPERATUR',
#    'unit': '°C',
#    'equidistance': 60}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 308.123,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-20T05:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'LT',
#    'longname': 'LUFTTEMPERATUR',
#    'unit': '°C',
#    'equidistance': 60},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 116.2,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-20T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}}],
#  [{'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-20T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 102.7,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 88.022,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-20T06:00:00+02:00',
#    'comment': {'shortDescription': 'bfg',
#     'longDescription': 'Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten.'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 75.158,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-21T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 62.45,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-22T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 55.948,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-22T06:00:00+02:00',
#    'comment': {'shortDescription': 'bfg',
#     'longDescription': 'Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten.'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 52.961,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-22T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}}],
#  [{'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-22T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 50.217,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-23T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 46.125,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 39.895,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-23T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 37.203,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-22T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 34.414,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-23T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 27.556,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-24T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 22.454,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-24T06:00:00+02:00',
#    'comment': {'shortDescription': 'bfg',
#     'longDescription': 'Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten.'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 16.707,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-25T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 1,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 10.402,
#     'validFrom': '2017-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-25T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 1,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 5.658,
#     'validFrom': '2017-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-26T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 1}],
#  [{'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-26T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 1,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 3.774,
#     'validFrom': '2017-11-01'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 1,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': -0.031,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-26T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 77.562,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-22T07:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 67.669,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-22T07:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 57.692,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-22T07:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 35.038,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-22T07:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15},
#   {'shortname': 'WT',
#    'longname': 'WASSERTEMPERATUR ROHDATEN',
#    'unit': '°C',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 24.529,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-22T07:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 16.106,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-22T07:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 7.998,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T19:00:00+02:00',
#    'end': '2024-07-22T07:00:00+02:00',
#    'comment': {'shortDescription': 'nwv-bfg',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 48.105,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-20T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 55.125,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-19T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 69.358,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-19T06:00:00+02:00',
#    'comment': {'shortDescription': 'wsa-md',
#     'longDescription': 'Vorhersagen und Abschätzungen vom: 18.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde.'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}],
#  [{'shortname': 'WV',
#    'longname': 'WASSERSTANDVORHERSAGE',
#    'unit': 'cm',
#    'equidistance': 120,
#    'start': '2024-07-18T18:00:00+02:00',
#    'end': '2024-07-24T06:00:00+02:00',
#    'comment': {'shortDescription': 'bfg',
#     'longDescription': 'Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten.'}},
#   {'shortname': 'W',
#    'longname': 'WASSERSTAND ROHDATEN',
#    'unit': 'cm',
#    'equidistance': 15,
#    'gaugeZero': {'unit': 'm. ü. NHN',
#     'value': 21.561,
#     'validFrom': '2019-11-01'}},
#   {'shortname': 'Q',
#    'longname': 'ABFLUSS_ROHDATEN',
#    'unit': 'm³/s',
#    'equidistance': 15}]]

# %%
response_str = json.dumps(responses)

# Load the JSON string into a Spark DataFrame
response_df = spark.read.json(spark.sparkContext.parallelize([response_str]))

# Flatten the dataframe
response_df = response_df.select(
    col("agency"),
    col("km").cast("double"),
    col("latitude").cast("double"),
    col("longitude").cast("double"),
    col("longname"),
    col("number"),
    col("shortname"),
    col("uuid"),
    col("water.longname").alias("water_longname"),
    col("water.shortname").alias("water_shortname")
)

# %%
response_df.printSchema()
response_df.show()
# Out:
# root
#  |-- agency: string (nullable = true)
#  |-- km: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- longname: string (nullable = true)
#  |-- number: string (nullable = true)
#  |-- shortname: string (nullable = true)
#  |-- uuid: string (nullable = true)
#  |-- water_longname: string (nullable = true)
#  |-- water_shortname: string (nullable = true)
#
# +-------------------+------+------------------+------------------+--------------------+--------+--------------------+--------------------+--------------+---------------+
# |             agency|    km|          latitude|         longitude|            longname|  number|           shortname|                uuid|water_longname|water_shortname|
# +-------------------+------+------------------+------------------+--------------------+--------+--------------------+--------------------+--------------+---------------+
# |STANDORT REGENSBURG|2249.5| 48.63719446076585|13.182352727075328|           VILSHOFEN|10089006|           VILSHOFEN|e6d68ab7-5c27-4f2...|         DONAU|          DONAU|
# |STANDORT REGENSBURG|2256.9|48.676629660669875|13.115159742918724|          HOFKIRCHEN|10088003|          HOFKIRCHEN|616dd98e-816d-4e1...|         DONAU|          DONAU|
# |STANDORT REGENSBURG|2284.4|48.824943730974475|12.962349954256105|          DEGGENDORF|10081004|          DEGGENDORF|53d40547-8a09-4b2...|         DONAU|          DONAU|
# |STANDORT REGENSBURG|2305.5| 48.87976613950202| 12.74721651873093|            PFELLING|10078000|            PFELLING|7fe63a95-8ff6-4cf...|         DONAU|          DONAU|
# |   STANDORT DRESDEN|  2.05| 50.87576232293828|14.235228651495222|              SCHÖNA|  501010|              SCHÖNA|7cb7461b-3530-4c0...|          ELBE|           ELBE|
# |   STANDORT DRESDEN| 55.63|51.054459765598125|13.738831783620384|             DRESDEN|  501060|             DRESDEN|70272185-b2b3-417...|          ELBE|           ELBE|
# |   STANDORT DRESDEN| 108.4| 51.31148159700113| 13.29334052168511|               RIESA|  501110|               RIESA|b04b739d-7ffa-41e...|          ELBE|           ELBE|
# |   STANDORT DRESDEN|154.15| 51.55368454231443| 13.01013060185494|              TORGAU|  501261|              TORGAU|83bbaedb-5d81-4bc...|          ELBE|           ELBE|
# |   STANDORT DRESDEN|214.14|  51.8565291449134|12.646310954043884|          WITTENBERG|  501420|          WITTENBERG|070b1eb4-3872-4e0...|          ELBE|           ELBE|
# |   STANDORT DRESDEN|245.62|51.851332646269746|12.355386908862236|           VOCKERODE|  501480|           VOCKERODE|ae93f2a5-612e-451...|          ELBE|           ELBE|
# |   STANDORT DRESDEN|261.16|51.856888350666324| 12.22327683144822|              DESSAU|  502000|              DESSAU|1edc5fa4-88af-47f...|          ELBE|           ELBE|
# |   STANDORT DRESDEN|274.75|51.857867459889704|12.058859064366539|                AKEN|  502010|                AKEN|094b96e5-caeb-46d...|          ELBE|           ELBE|
# | STANDORT MAGDEBURG|294.82|51.984833781910986|11.882246426452303|               BARBY|  502070|               BARBY|939f82ec-15a9-49c...|          ELBE|           ELBE|
# | STANDORT MAGDEBURG|326.67| 52.12969780011619|11.644334378196522|MAGDEBURG-STROMBR...|  502180|MAGDEBURG-STROMBR...|ccccb57f-a2f9-418...|          ELBE|           ELBE|
# | STANDORT MAGDEBURG|333.12|  52.1809527613989| 11.68265328901543|           ROTHENSEE|  502210|           ROTHENSEE|e30f2e83-b80b-4b9...|          ELBE|           ELBE|
# | STANDORT MAGDEBURG| 343.6| 52.24974836387516|11.737554478861217|         NIEGRIPP AP|  502240|         NIEGRIPP AP|3adf88fd-fd7a-41d...|          ELBE|           ELBE|
# | STANDORT MAGDEBURG|388.26|52.541306122508246|11.978056091329778|         TANGERMÜNDE|  502350|         TANGERMÜNDE|13e91b77-90f3-41a...|          ELBE|           ELBE|
# | STANDORT MAGDEBURG|416.06| 52.78476981254726|12.031305110634692|              SANDAU|  502430|              SANDAU|f4c55f77-ab80-4e0...|          ELBE|           ELBE|
# | STANDORT MAGDEBURG|453.98|52.985528648267035| 11.75944299732184|         WITTENBERGE|  503050|         WITTENBERGE|cbf3cd49-91bd-49c...|          ELBE|           ELBE|
# | STANDORT LAUENBURG| 504.7| 53.14033320310089|11.242911991019788|              DÖMITZ| 5910025|              DÖMITZ|6e3ea719-48b1-408...|          ELBE|           ELBE|
# +-------------------+------+------------------+------------------+--------------------+--------+--------------------+--------------------+--------------+---------------+
# only showing top 20 rows

# %%
"""
    Apply AVE model, with four tables:
    - "response": contains the information that every record has
    - "Timeseries Item": each row corresponds to an item of timeseries (each timeseries field in a record can have multiple items)
    - "Timeseries Attribute": the field appeared in a timeseries item. We might want to track its type (?) and name
    - "Timeseries Attribute Value": contains the value, the attribute (that the value corresponds to), and the item which the mentioned attribute belongs to

    Difficulty:
    - How can we make sure two fields are different/the same?
    - The value always has to be stored as string/text
    - Not easy to impute the type of a field 
"""

def parse_key_value(json_dict, parent):
    key_value_list = []
    for key, value in json_dict.items():
        if isinstance(value, dict):
            if parent == "": next_parent = key
            else: next_parent = parent + "." + key
            key_value_list.extend(parse_key_value(value, next_parent))
        else:
            if parent == "": this_key = key
            else: this_key = parent + "." + key
            key_value_list.append((this_key, str(value)))
    return key_value_list

def read_key_value(json_str):
    json_dict = json.loads(json_str.replace("\'", "\""))
    print(json_dict)
    key_value_list = parse_key_value(json_dict, "")
    return key_value_list
    
timeseries_df = spark.createDataFrame(timeseries_data, ['uuid', 'item_id', 'timeseries_data'])

schema = ArrayType(StructType([
    StructField("key", StringType(), True),
    StructField("value", StringType(), True)
]))
explode_udf = udf(read_key_value, schema)

timeseries_parsed_df = timeseries_df.withColumn("timeseries_parsed", explode_udf(col('timeseries_data')))
timeseries_parsed_df.show(1,truncate=False)
# Out:
# +------------------------------------+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |uuid                                |item_id                              |timeseries_data                                                                                                                                                               |timeseries_parsed                                                                                                                                                             |
# +------------------------------------+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd0|{"shortname": "W", "longname": "WASSERSTAND ROHDATEN", "unit": "cm", "equidistance": 15, "gaugeZero": {"unit": "m. \u00fc. NHN", "value": 297.043, "validFrom": "2019-01-01"}}|[{shortname, W}, {longname, WASSERSTAND ROHDATEN}, {unit, cm}, {equidistance, 15}, {gaugeZero.unit, m. ü. NHN}, {gaugeZero.value, 297.043}, {gaugeZero.validFrom, 2019-01-01}]|
# +------------------------------------+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 1 row

# %%
timeseries_parsed_df = timeseries_parsed_df.withColumn("exploded_pair", explode(col('timeseries_parsed')))
timeseries_parsed_df = timeseries_parsed_df.withColumn("key", col("exploded_pair").getItem("key")) \
                .withColumn("value", col("exploded_pair").getItem("value"))
timeseries_parsed_df = timeseries_parsed_df.drop("timeseries_data", "exploded_pair","timeseries_parsed")
timeseries_parsed_df.show(truncate=False)
# Out:
# +------------------------------------+-------------------------------------+------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |uuid                                |item_id                              |key                     |value                                                                                                                                                                                                                                   |
# +------------------------------------+-------------------------------------+------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd0|shortname               |W                                                                                                                                                                                                                                       |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd0|longname                |WASSERSTAND ROHDATEN                                                                                                                                                                                                                    |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd0|unit                    |cm                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd0|equidistance            |15                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd0|gaugeZero.unit          |m. ü. NHN                                                                                                                                                                                                                               |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd0|gaugeZero.value         |297.043                                                                                                                                                                                                                                 |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd0|gaugeZero.validFrom     |2019-01-01                                                                                                                                                                                                                              |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd1|shortname               |WV                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd1|longname                |WASSERSTANDVORHERSAGE                                                                                                                                                                                                                   |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd1|unit                    |cm                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd1|equidistance            |120                                                                                                                                                                                                                                     |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd1|start                   |2024-07-18T19:00:00+02:00                                                                                                                                                                                                               |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd1|end                     |2024-07-22T05:00:00+02:00                                                                                                                                                                                                               |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd1|comment.shortDescription|nwv-bfg                                                                                                                                                                                                                                 |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd1|comment.longDescription |Vorhersagen und Abschätzungen vom: 18.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde|
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd2|shortname               |LT                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd2|longname                |LUFTTEMPERATUR                                                                                                                                                                                                                          |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd2|unit                    |°C                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd2|equidistance            |60                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd|e6d68ab7-5c27-4f25-896f-11dbf04056cd3|shortname               |WT                                                                                                                                                                                                                                      |
# +------------------------------------+-------------------------------------+------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
timeseries_item = timeseries_df.select(col("item_id"),col("uuid"))
timeseries_item.show(truncate=False)
# Out:
# +-------------------------------------+------------------------------------+
# |item_id                              |uuid                                |
# +-------------------------------------+------------------------------------+
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd0|e6d68ab7-5c27-4f25-896f-11dbf04056cd|
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|e6d68ab7-5c27-4f25-896f-11dbf04056cd|
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd2|e6d68ab7-5c27-4f25-896f-11dbf04056cd|
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd3|e6d68ab7-5c27-4f25-896f-11dbf04056cd|
# |616dd98e-816d-4e17-b8cd-57b163dbc8a20|616dd98e-816d-4e17-b8cd-57b163dbc8a2|
# |616dd98e-816d-4e17-b8cd-57b163dbc8a21|616dd98e-816d-4e17-b8cd-57b163dbc8a2|
# |616dd98e-816d-4e17-b8cd-57b163dbc8a22|616dd98e-816d-4e17-b8cd-57b163dbc8a2|
# |616dd98e-816d-4e17-b8cd-57b163dbc8a23|616dd98e-816d-4e17-b8cd-57b163dbc8a2|
# |616dd98e-816d-4e17-b8cd-57b163dbc8a24|616dd98e-816d-4e17-b8cd-57b163dbc8a2|
# |53d40547-8a09-4b25-988c-2e6d8d8d98ee0|53d40547-8a09-4b25-988c-2e6d8d8d98ee|
# |53d40547-8a09-4b25-988c-2e6d8d8d98ee1|53d40547-8a09-4b25-988c-2e6d8d8d98ee|
# |53d40547-8a09-4b25-988c-2e6d8d8d98ee2|53d40547-8a09-4b25-988c-2e6d8d8d98ee|
# |53d40547-8a09-4b25-988c-2e6d8d8d98ee3|53d40547-8a09-4b25-988c-2e6d8d8d98ee|
# |7fe63a95-8ff6-4cff-9a29-a124136516b50|7fe63a95-8ff6-4cff-9a29-a124136516b5|
# |7fe63a95-8ff6-4cff-9a29-a124136516b51|7fe63a95-8ff6-4cff-9a29-a124136516b5|
# |7fe63a95-8ff6-4cff-9a29-a124136516b52|7fe63a95-8ff6-4cff-9a29-a124136516b5|
# |7fe63a95-8ff6-4cff-9a29-a124136516b53|7fe63a95-8ff6-4cff-9a29-a124136516b5|
# |7cb7461b-3530-4c01-8978-7f676b8f71ed0|7cb7461b-3530-4c01-8978-7f676b8f71ed|
# |7cb7461b-3530-4c01-8978-7f676b8f71ed1|7cb7461b-3530-4c01-8978-7f676b8f71ed|
# |7cb7461b-3530-4c01-8978-7f676b8f71ed2|7cb7461b-3530-4c01-8978-7f676b8f71ed|
# +-------------------------------------+------------------------------------+
# only showing top 20 rows

# %%
timeseries_attribute_df = timeseries_parsed_df.select(col("key").alias("attribute")).dropDuplicates()
timeseries_attribute_df.show(truncate=False)
# Out:
# +------------------------+
# |attribute               |
# +------------------------+
# |equidistance            |
# |longname                |
# |comment.shortDescription|
# |end                     |
# |gaugeZero.unit          |
# |unit                    |
# |comment.longDescription |
# |gaugeZero.validFrom     |
# |start                   |
# |shortname               |
# |gaugeZero.value         |
# +------------------------+

# %%
timeseries_attr_val_df = timeseries_parsed_df.select(col("item_id"), col("key").alias("attribute"), col("value"))
timeseries_attr_val_df.show(truncate=False)
# Out:
# +-------------------------------------+------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |item_id                              |attribute               |value                                                                                                                                                                                                                                   |
# +-------------------------------------+------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd0|shortname               |W                                                                                                                                                                                                                                       |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd0|longname                |WASSERSTAND ROHDATEN                                                                                                                                                                                                                    |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd0|unit                    |cm                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd0|equidistance            |15                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd0|gaugeZero.unit          |m. ü. NHN                                                                                                                                                                                                                               |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd0|gaugeZero.value         |297.043                                                                                                                                                                                                                                 |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd0|gaugeZero.validFrom     |2019-01-01                                                                                                                                                                                                                              |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|shortname               |WV                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|longname                |WASSERSTANDVORHERSAGE                                                                                                                                                                                                                   |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|unit                    |cm                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|equidistance            |120                                                                                                                                                                                                                                     |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|start                   |2024-07-18T19:00:00+02:00                                                                                                                                                                                                               |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|end                     |2024-07-22T05:00:00+02:00                                                                                                                                                                                                               |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|comment.shortDescription|nwv-bfg                                                                                                                                                                                                                                 |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd1|comment.longDescription |Vorhersagen und Abschätzungen vom: 18.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde|
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd2|shortname               |LT                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd2|longname                |LUFTTEMPERATUR                                                                                                                                                                                                                          |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd2|unit                    |°C                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd2|equidistance            |60                                                                                                                                                                                                                                      |
# |e6d68ab7-5c27-4f25-896f-11dbf04056cd3|shortname               |WT                                                                                                                                                                                                                                      |
# +-------------------------------------+------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
import psycopg2
from psycopg2.extras import execute_values

def insert_data(table, df, conn_param):
    columns = [f'"{col}"' for col in df.schema.names]
    data = [tuple(row) for row in df.collect()]

    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()
    insert_query = f"INSERT INTO {table} ({', '.join(columns)}) VALUES %s"
    execute_values(cursor, insert_query, data)
    conn.commit()
    cursor.close()
    conn.close()

# %%
conn_params = {
    "dbname": "db",
    "user": "postgres",
    "password": "12345",
    "host": "pg_container",
    "port": 5432
}
insert_data("responses", response_df, conn_params)
insert_data("timeseries_item", timeseries_item, conn_params)
insert_data("timeseries_attribute", timeseries_attribute_df, conn_params)
insert_data("timeseries_value", timeseries_attr_val_df, conn_params)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# Cell In[139], line 11
#       9 insert_data("timeseries_item", timeseries_item, conn_params)
#      10 insert_data("timeseries_attribute", timeseries_attribute_df, conn_params)
# ---> 11 insert_data("timeseries_value", timeseries_attr_val_df, conn_params)
#
# Cell In[138], line 11, in insert_data(table, df, conn_param)
#       9 cursor = conn.cursor()
#      10 insert_query = f"INSERT INTO {table} ({', '.join(columns)}) VALUES %s"
# ---> 11 execute_values(cursor, insert_query, data)
#      12 conn.commit()
#      13 cursor.close()
#
# File /opt/conda/lib/python3.11/site-packages/psycopg2/extras.py:1299, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1297     parts.append(b',')
#    1298 parts[-1:] = post
# -> 1299 cur.execute(b''.join(parts))
#    1300 if fetch:
#    1301     result.extend(cur.fetchall())
#
# UndefinedColumn: column "item_id" of relation "timeseries_value" does not exist
# LINE 1: INSERT INTO timeseries_value ("item_id", "attribute", "value...
#                                       ^

# %%
"""
    Basically, there are five types of data the timeseries contains:
    - WASSERSTAND ROHDATEN: water level raw data
    - WASSERSTANDVORHERSAGE: water level forecast
    - WASSERTEMPERATUR: water temperature
    - WASSERTEMPERATUR ROHDATEN: water temperature forecast (?)
    - LUFTTEMPERATUR: air temperature 
    - ABFLUSS: drain
    - ABFLUSS_ROHDATEN: drain forecast (?)
    
    There might be other type of timeseries data; therefore, we will try to extract the name of each type (category), then create a dataframe
    for each of the category. Each dataframe will be stored as a new table in the database.
"""

timeseries_df = spark.createDataFrame(timeseries_data)
timeseries_df = timeseries_df.withColumn("timeseries_data", explode("timeseries_data")).select("*")
timeseries_df = timeseries_df.withColumn("category",element_at(col("timeseries_data"),"longname"))
timeseries_grouped = timeseries_df.groupBy("category").agg(collect_list(struct(col("uuid"), col("timeseries_data"))).alias("timeseries_data"))
timeseries_grouped.show(truncate=True)

# joined_df = df_flattened.join(timeseries_df, df_flattened.uuid == timeseries_df.uuid, 'inner').drop(timeseries_df.uuid)
# joined_df.printSchema()
# joined_df.show(truncate=False)
# print(joined_df.head(5))
# Out:
# +--------------------+--------------------+
# |            category|     timeseries_data|
# +--------------------+--------------------+
# |WASSERSTANDVORHER...|[{e6d68ab7-5c27-4...|
# |      LUFTTEMPERATUR|[{e6d68ab7-5c27-4...|
# |    WASSERTEMPERATUR|[{e6d68ab7-5c27-4...|
# |WASSERSTAND ROHDATEN|[{e6d68ab7-5c27-4...|
# |             ABFLUSS|[{616dd98e-816d-4...|
# |    ABFLUSS_ROHDATEN|[{7cb7461b-3530-4...|
# |WASSERTEMPERATUR ...|[{a6ee8177-107b-4...|
# +--------------------+--------------------+

# %%
distinct_category = timeseries_grouped.select('category').distinct().rdd.map(lambda row: row[0]).collect()
distinct_category
# Out:
# ['WASSERSTANDVORHERSAGE',
#  'LUFTTEMPERATUR',
#  'WASSERTEMPERATUR',
#  'WASSERSTAND ROHDATEN',
#  'ABFLUSS',
#  'ABFLUSS_ROHDATEN',
#  'WASSERTEMPERATUR ROHDATEN']

# %%
timeseries_df = {}
for category in distinct_category:
    temp_df = timeseries_grouped.filter(timeseries_grouped["category"] == category) \
                                .select(explode("timeseries_data").alias("timeseries_data")) \
                                .select(col("timeseries_data.uuid"), col("timeseries_data.timeseries_data"))
    timeseries_df[category] = temp_df.select("uuid",explode("timeseries_data")) \
                                             .groupBy("uuid").pivot("key").agg(first("value"))
    
timeseries_df["WASSERSTANDVORHERSAGE"].show()
# Out:
# +--------------------+--------------------+--------------------+------------+--------------------+---------+--------------------+----+
# |                uuid|             comment|                 end|equidistance|            longname|shortname|               start|unit|
# +--------------------+--------------------+--------------------+------------+--------------------+---------+--------------------+----+
# |070b1eb4-3872-4e0...|{longDescription=...|2024-07-16T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |094b96e5-caeb-46d...|{longDescription=...|2024-07-16T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |13e91b77-90f3-41a...|{longDescription=...|2024-07-18T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |1d26e504-7f9e-480...|{longDescription=...|2024-07-16T07:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T17:00:...|  cm|
# |1edc5fa4-88af-47f...|{longDescription=...|2024-07-16T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |33e0bce0-13df-4ff...|{longDescription=...|2024-07-20T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |3adf88fd-fd7a-41d...|{longDescription=...|2024-07-17T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |46a3350b-f3e6-4f5...|{longDescription=...|2024-07-14T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |4c7d796a-39f2-4f2...|{longDescription=...|2024-07-16T07:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T17:00:...|  cm|
# |53d40547-8a09-4b2...|{longDescription=...|2024-07-15T05:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T17:00:...|  cm|
# |616dd98e-816d-4e1...|{longDescription=...|2024-07-16T05:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T17:00:...|  cm|
# |665be0fe-5e38-43f...|{longDescription=...|2024-07-16T07:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T17:00:...|  cm|
# |67d6e882-b60c-40d...|{longDescription=...|2024-07-20T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |6e3ea719-48b1-408...|{longDescription=...|2024-07-19T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |70272185-b2b3-417...|{longDescription=...|2024-07-14T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |7cb7461b-3530-4c0...|{longDescription=...|2024-07-14T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |7fe63a95-8ff6-4cf...|{longDescription=...|2024-07-15T05:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T17:00:...|  cm|
# |83bbaedb-5d81-4bc...|{longDescription=...|2024-07-15T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# |8f7e5f92-1153-4f9...|{longDescription=...|2024-07-16T07:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T17:00:...|  cm|
# |939f82ec-15a9-49c...|{longDescription=...|2024-07-17T06:00:...|         120|WASSERSTANDVORHER...|       WV|2024-07-13T16:00:...|  cm|
# +--------------------+--------------------+--------------------+------------+--------------------+---------+--------------------+----+
# only showing top 20 rows

# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Downloading psycopg2_binary-2.9.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 6.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9

# %%
import psycopg2
from psycopg2.extras import execute_values

def table_exists(table_name, conn_params):
    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()
    cursor.execute("""
        SELECT EXISTS (
            SELECT 1
            FROM information_schema.tables 
            WHERE table_schema = 'public'
            AND table_name = %s
        );
    """, (table_name,))
    exists = cursor.fetchone()[0]
    cursor.close()
    conn.close()
    return exists

# %%
def convert_type(spark_type):
    mapping = {
        "bigint": "BIGINT",
        "int": "INTEGER",
        "string": "VARCHAR",
        "double": "DOUBLE PRECISION"
    }
    return mapping.get(spark_type, "TEXT")

# %%
def create_table(df, table_name, conn_params):
    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()
    
    columns = ", ".join([f'"{field.name}" {convert_type(field.dataType.simpleString())}' for field in df.schema.fields])
    create_table_sql = f"CREATE TABLE {table_name} ({columns});"
    print(create_table_sql)
    cursor.execute(create_table_sql)
    conn.commit()
    cursor.close()
    conn.close()

# %%
def insert_data(table, df, conn_param):
    columns = [f'"{col}"' for col in df.schema.names]
    data = [tuple(row) for row in df.collect()]

    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()
    insert_query = f"INSERT INTO {table} ({', '.join(columns)}) VALUES %s"
    execute_values(cursor, insert_query, data)
    conn.commit()
    cursor.close()
    conn.close()

# %%
conn_params = {
    "dbname": "db",
    "user": "postgres",
    "password": "12345",
    "host": "pg_container",
    "port": 5432
}

for category in distinct_category:
    table_name = category.replace(" ", "_").lower()
    if not table_exists(table_name, conn_params):
        create_table(timeseries_df[category], table_name, conn_params)
    insert_data(table_name, timeseries_df[category], conn_params)
# Out:
# CREATE TABLE wasserstandvorhersage ("uuid" VARCHAR, "comment" VARCHAR, "end" VARCHAR, "equidistance" VARCHAR, "longname" VARCHAR, "shortname" VARCHAR, "start" VARCHAR, "unit" VARCHAR);
# CREATE TABLE lufttemperatur ("uuid" VARCHAR, "equidistance" VARCHAR, "longname" VARCHAR, "shortname" VARCHAR, "unit" VARCHAR);
# CREATE TABLE wassertemperatur ("uuid" VARCHAR, "comment" VARCHAR, "equidistance" VARCHAR, "longname" VARCHAR, "shortname" VARCHAR, "unit" VARCHAR);
# CREATE TABLE wasserstand_rohdaten ("uuid" VARCHAR, "equidistance" VARCHAR, "gaugeZero" VARCHAR, "longname" VARCHAR, "shortname" VARCHAR, "unit" VARCHAR);
# CREATE TABLE abfluss ("uuid" VARCHAR, "equidistance" VARCHAR, "longname" VARCHAR, "shortname" VARCHAR, "unit" VARCHAR);
# CREATE TABLE abfluss_rohdaten ("uuid" VARCHAR, "equidistance" VARCHAR, "longname" VARCHAR, "shortname" VARCHAR, "unit" VARCHAR);
# CREATE TABLE wassertemperatur_rohdaten ("uuid" VARCHAR, "equidistance" VARCHAR, "longname" VARCHAR, "shortname" VARCHAR, "unit" VARCHAR);

# %%
conn = psycopg2.connect(**conn_params)
cursor = conn.cursor()
for category in distinct_category:
    cursor.execute("SELECT * FROM lufttemperatur")

# %%
conn = psycopg2.connect(**conn_params)
cursor = conn.cursor()
cursor.execute("SELECT * FROM wasserstandvorhersage ")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('070b1eb4-3872-4e07-b2e5-e25fd9251b93', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-16T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('094b96e5-caeb-46d3-a8ee-d44182add069', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-16T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('13e91b77-90f3-41a5-a320-641748e9c311', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-18T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('1d26e504-7f9e-480a-b52c-5932be6549ab', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-16T07:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('1edc5fa4-88af-47f5-95a4-0e77a06fe8b1', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-16T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('33e0bce0-13df-4ffc-be9d-f1a79e795e1c', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-20T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('3adf88fd-fd7a-41d0-84f5-1143c98a6564', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-17T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('46a3350b-f3e6-4f5d-a297-2652c43bfac8', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-14T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('4c7d796a-39f2-4f26-97a9-3aad01713e29', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-16T07:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('53d40547-8a09-4b25-988c-2e6d8d8d98ee', '{longDescription=Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-15T05:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('616dd98e-816d-4e17-b8cd-57b163dbc8a2', '{longDescription=Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-16T05:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('665be0fe-5e38-43f6-8b04-02a93bdbeeb4', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-16T07:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('67d6e882-b60c-40d3-975c-a6d7a2b4e40a', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-20T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('6e3ea719-48b1-408a-bc55-0986c1e94cd5', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-19T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('70272185-b2b3-4178-96b8-43bea330dcae', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-14T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('7cb7461b-3530-4c01-8978-7f676b8f71ed', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-14T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('7fe63a95-8ff6-4cff-9a29-a124136516b5', '{longDescription=Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-15T05:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('83bbaedb-5d81-4bc6-9f66-3bd700c99c1f', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-15T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('8f7e5f92-1153-4f93-acba-ca48670c8ca9', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-16T07:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('939f82ec-15a9-49c8-8828-dc2f8a2d49e2', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-17T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('9598e4cb-0849-401e-bba0-689234b27644', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-16T07:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('a6ee8177-107b-47dd-bcfd-30960ccc6e9c', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-16T07:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('ae93f2a5-612e-4514-b5fd-9c8aecdd73c7', '{longDescription=Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten., shortDescription=bfg}', '2024-07-16T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('b04b739d-7ffa-41ee-9eb9-95cb1b4ef508', '{longDescription=Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten., shortDescription=bfg}', '2024-07-14T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('c0f51e35-d0e8-4318-afaf-c5fcbc29f4c1', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 07:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-16T07:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('c203d5fb-96d7-4643-b2ef-b13b1d88c75b', '{longDescription=Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten., shortDescription=bfg}', '2024-07-18T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('cbf3cd49-91bd-49cc-8926-ccc6c0e7eca4', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-19T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('ccccb57f-a2f9-4183-ae88-5710d3afaefd', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-17T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('d9289367-c8aa-4b6a-b1ad-857fec94c6bb', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-20T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('e30f2e83-b80b-4b96-8f39-fa60317afcc7', '{longDescription=Vorhersagen und Abschätzungen vom: 12.07.2024 um 06:00 Uhr, Quelle: WSA ElbeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde., shortDescription=wsa-md}', '2024-07-16T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')
# ('e6d68ab7-5c27-4f25-896f-11dbf04056cd', '{longDescription=Vorhersagen und Abschätzungen vom: 13.07.2024 um 05:00 Uhr, Quelle: Bundesanstalt für GewässerkundeWeitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde, shortDescription=nwv-bfg}', '2024-07-17T05:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T17:00:00+02:00', 'cm')
# ('f4c55f77-ab80-4e00-bed3-aa6631aba074', '{longDescription=Weitere Informationen zur Unterscheidung von Vorhersage und Abschätzung finden Sie auf den Seiten der Bundesanstalt für Gewässerkunde sowie eine aktuelle Gegenüberstellung der vorhergesagten/abgeschätzten Werte mit den Messdaten., shortDescription=bfg}', '2024-07-18T06:00:00+02:00', '120', 'WASSERSTANDVORHERSAGE', 'WV', '2024-07-13T16:00:00+02:00', 'cm')

# %%
import psycopg2
from psycopg2.extras import execute_values

conn_params = {
    "dbname": "db",
    "user": "postgres",
    "password": "12345",
    "host": "pg_container",
    "port": 5432
}

conn = psycopg2.connect(**conn_params)
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE station_timeseries (
    agency VARCHAR(255),
    km DOUBLE PRECISION,
    latitude DOUBLE PRECISION,
    longitude DOUBLE PRECISION,
    longname VARCHAR(255),
    number VARCHAR(255),
    shortname VARCHAR(255),
    uuid UUID,
    water_longname VARCHAR(255),
    water_shortname VARCHAR(255),
    category VARCHAR(255),
    timeseries_uuid UUID,
    timeseries_end TIMESTAMPTZ,
    timeseries_unit VARCHAR(50),
    timeseries_start TIMESTAMPTZ,
    timeseries_comment TEXT,
    timeseries_longname VARCHAR(255),
    timeseries_shortname VARCHAR(50),
    timeseries_equidistance VARCHAR(50)
);


""")
conn.commit()

# %%
import psycopg2
from psycopg2.extras import execute_values

# Function to insert data into PostgreSQL
def insert_data(table, data, columns):
    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()
    insert_query = f"INSERT INTO {table} ({', '.join(columns)}) VALUES %s"
    execute_values(cursor, insert_query, data)
    conn.commit()
    cursor.close()
    conn.close()

# Convert Spark DataFrame to list of tuples for insertion into PostgreSQL
joined_data = [tuple(row) for row in joined_df.collect()]

# Define the columns
columns = [
    "agency", "km", "latitude", "longitude", "longname", "number", "shortname", 
    "uuid", "water_longname", "water_shortname", "timeseries_uuid", "category", 
    "unit", "start", "end", "comment", "equidistance"
]

# Insert joined data into PostgreSQL
insert_data("station_timeseries", joined_data, columns)

conn = psycopg2.connect(**conn_params)
cursor = conn.cursor()
cursor.execute("SELECT * FROM station_timeseries")
rows = cursor.fetchall()
for row in rows:
    print(row)

cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 15
#      12     conn.close()
#      14 # Convert Spark DataFrame to list of tuples for insertion into PostgreSQL
# ---> 15 joined_data = [tuple(row) for row in joined_df.collect()]
#      17 # Define the columns
#      18 columns = [
#      19     "agency", "km", "latitude", "longitude", "longname", "number", "shortname",
#      20     "uuid", "water_longname", "water_shortname", "timeseries_uuid", "category",
#      21     "unit", "start", "end", "comment", "equidistance"
#      22 ]
#
# NameError: name 'joined_df' is not defined
